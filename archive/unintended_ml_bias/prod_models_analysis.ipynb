# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import pandas as pd
import numpy as np
import pkg_resources
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import model_bias_analysis

# autoreload makes it easier to interactively work on code in the model_bias_analysis module.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Shared functions

# %%
def convert_to_boolean_labels(labels):
    return np.where(labels >= 0.5, True, False)

# %%
def scatterplot(results, model_1, model_2, y_label, ylim=(0.8, 1.0)):
    fig = plt.figure(figsize=(15, 5))
    ax = fig.add_subplot(111)
    #bar_width = 0.35
    point_size=15
    for i, (_index, row) in enumerate(results.iterrows()):
        # For each subgroup, we plot a 1D scatterplot. The x-value is the position
        # of the item in the dataframe. To change the ordering of the subgroups,
        # sort the dataframe before passing to this function.
        x = [i] * 2
        y = [row[model_1], row[model_2]]
        ax.scatter(x, y, s=0)
        #if (abs(y[1] - y[0]) > 0.003):
        plt.arrow(x[0],y[0], 0, y[1] - y[0], length_includes_head=True, shape='full', head_starts_at_zero=False, head_length=0.005, head_width=0.3, color='black')
    ax.set_xticklabels(results['subgroup'], rotation=90)
    ax.set_xticks(range(len(results)))
    ax.set_ylim(ylim)
    ax.set_title(y_label)
    fig.tight_layout()
    #fig.savefig('/tmp/%s_%s.eps' % (file_name, values_col), format='eps')

# %%
# MADLIBS set up

# %%
models = [
    'Rock:TOXICITY',
    'RockV5_1:TOXICITY',
    'RockV6_1:TOXICITY',
]

# %%
madlibs = pd.read_csv('eval_datasets/bias_madlibs_77k_scored_prod_models.csv')

# %%
# Add columns for each subgroup.
f = open('bias_madlibs_data/adjectives_people.txt', 'r')
terms = [line.strip() for line in f]
model_bias_analysis.add_subgroup_columns_from_text(madlibs, 'Text', terms)

# %%
madlibs['label_bool'] = madlibs.apply(lambda row: row.Label == 'BAD', axis=1)

# %%
madlibs_results = model_bias_analysis.compute_bias_metrics_for_models(madlibs, terms, models, 'label_bool')

# %%
# Real Data set up

# %%
human_labels = [
 'toxicity',
 'severe_toxicity',
 'obscene',
 'sexual_explicit',
 'identity_attack',
 'insult',
 'threat',
 'male',
 'female',
 'transgender',
 'other_gender',
 'heterosexual',
 'homosexual_gay_or_lesbian',
 'bisexual',
 'other_sexual_orientation',
 'christian',
 'jewish',
 'muslim',
 'hindu',
 'buddhist',
 'atheist',
 'other_religion',
 'black',
 'white',
 'asian',
 'latino',
 'other_race_or_ethnicity',
 'physical_disability',
 'intellectual_or_learning_disability',
 'psychiatric_or_mental_illness',
 'other_disability']

identities = [
 'male',
 'female',
 'transgender',
 'heterosexual',
 'homosexual_gay_or_lesbian',
 'bisexual',
 'christian',
 'jewish',
 'muslim',
 'hindu',
 #'buddhist',
 'atheist',
 'other_religion',
 'black',
 'white',
 'asian',
 'latino',
 'other_race_or_ethnicity',
 #'physical_disability',
 'intellectual_or_learning_disability',
 'psychiatric_or_mental_illness']

# %%
real_data = pd.read_csv('eval_datasets/identity_labeled_scored.csv')

# %%
real_data_models = ['rock_toxicity', 'rock_v6_1_toxicity']

# %%
for human_label in human_labels:
    real_data[human_label] = convert_to_boolean_labels(real_data[human_label])

# %%
real_data = real_data[(real_data.comment_text.str.len() < 100)]

# %%
len(real_data)
# Out:
# 480897

# %%
real_data_results = model_bias_analysis.compute_bias_metrics_for_models(real_data, identities, real_data_models, 'toxicity')

# %%
# RESULTS

# %%
scatterplot(madlibs_results, 'Rock:TOXICITY_negative_aeg', 'RockV6_1:TOXICITY_negative_aeg', 'Synthetic Data Negative AEG', ylim=(-0.5,0.5))
scatterplot(madlibs_results, 'Rock:TOXICITY_positive_aeg', 'RockV6_1:TOXICITY_positive_aeg', 'Synthetic Data Positive AEG', ylim=(-0.5,0.5))

# %%
# REAL DATA

# %%
real_data_results
# Out:
#     rock_toxicity_negative_aeg  rock_toxicity_negative_cross_auc  \
# 0                     0.132004                          0.912435
# 1                     0.171680                          0.900022
# 2                     0.337123                          0.823198
# 3                     0.342394                          0.727690
# 4                     0.432745                          0.574651
# 5                     0.328307                          0.821191
# 6                     0.124348                          0.931745
# 7                     0.338841                          0.793965
# 8                     0.335690                          0.812741
# 9                     0.124516                          0.948589
# 10                    0.235143                          0.880699
# 11                    0.140058                          0.940331
# 12                    0.354494                          0.785848
# 13                    0.331462                          0.807969
# 14                    0.141801                          0.918780
# 15                    0.156354                          0.896735
# 16                    0.199242                          0.898787
# 17                    0.289899                          0.913476
# 18                    0.359087                          0.787028
#
#     rock_toxicity_positive_aeg  rock_toxicity_positive_cross_auc  \
# 0                    -0.034193                          0.941778
# 1                    -0.043220                          0.936900
# 2                    -0.174792                          0.924981
# 3                    -0.027705                          0.937055
# 4                     0.104925                          0.981038
# 5                    -0.082739                          0.936826
# 6                    -0.089219                          0.927479
# 7                    -0.026794                          0.952978
# 8                    -0.064664                          0.941234
# 9                    -0.018074                          0.965417
# 10                   -0.004371                          0.964939
# 11                   -0.112892                          0.944366
# 12                   -0.047397                          0.945175
# 13                   -0.055756                          0.941067
# 14                   -0.109629                          0.918248
# 15                   -0.105020                          0.906313
# 16                   -0.148277                          0.937983
# 17                   -0.238701                          0.835041
# 18                   -0.053256                          0.950483
#
#     rock_toxicity_subgroup_auc                             subgroup  \
# 0                     0.905344                                 male
# 1                     0.883307                               female
# 2                     0.740532                          transgender
# 3                     0.721014                         heterosexual
# 4                     0.705605            homosexual_gay_or_lesbian
# 5                     0.825000                             bisexual
# 6                     0.908091                            christian
# 7                     0.795529                               jewish
# 8                     0.782752                               muslim
# 9                     0.956522                                hindu
# 10                    0.913462                              atheist
# 11                    0.932099                       other_religion
# 12                    0.765803                                black
# 13                    0.783766                                white
# 14                    0.876223                                asian
# 15                    0.827863                               latino
# 16                    0.884921              other_race_or_ethnicity
# 17                    0.571429  intellectual_or_learning_disability
# 18                    0.781543        psychiatric_or_mental_illness
#
#     subset_size  rock_v6_1_toxicity_negative_aeg  \
# 0          4877                         0.116253
# 1          4004                         0.176721
# 2           183                         0.269645
# 3            58                         0.211658
# 4           743                         0.297394
# 5            18                         0.178914
# 6          2321                         0.091935
# 7           394                         0.328738
# 8          1624                         0.264992
# 9            26                         0.084734
# 10          109                         0.250334
# 11           33                         0.138036
# 12         1054                         0.400053
# 13         2230                         0.372605
# 14          437                         0.207266
# 15          171                         0.164795
# 16           37                         0.323143
# 17           11                         0.291631
# 18          497                         0.287342
#
#     rock_v6_1_toxicity_negative_cross_auc  rock_v6_1_toxicity_positive_aeg  \
# 0                                0.930743                        -0.047021
# 1                                0.918163                        -0.038354
# 2                                0.889995                        -0.178866
# 3                                0.874545                        -0.189757
# 4                                0.824502                        -0.078874
# 5                                0.908267                        -0.182234
# 6                                0.944838                        -0.110199
# 7                                0.841121                        -0.070236
# 8                                0.882697                        -0.130723
# 9                                0.935417                        -0.179336
# 10                               0.906166                        -0.050051
# 11                               0.960689                        -0.042919
# 12                               0.754664                        -0.021460
# 13                               0.830036                        -0.080915
# 14                               0.901923                        -0.059024
# 15                               0.899236                        -0.101899
# 16                               0.873779                        -0.041813
# 17                               0.831522                        -0.234154
# 18                               0.857795                        -0.065728
#
#     rock_v6_1_toxicity_positive_cross_auc  rock_v6_1_toxicity_subgroup_auc
# 0                                0.950209                         0.919895
# 1                                0.947000                         0.899304
# 2                                0.896024                         0.768658
# 3                                0.934144                         0.793478
# 4                                0.927532                         0.768287
# 5                                0.911510                         0.837500
# 6                                0.937015                         0.920346
# 7                                0.949518                         0.807694
# 8                                0.929485                         0.812553
# 9                                0.961519                         0.927536
# 10                               0.968390                         0.936699
# 11                               0.956915                         0.975309
# 12                               0.968992                         0.775821
# 13                               0.959915                         0.817256
# 14                               0.933266                         0.857248
# 15                               0.936877                         0.852290
# 16                               0.973851                         0.920635
# 17                               0.816976                         0.535714
# 18                               0.950937                         0.837768

# %%
scatterplot(real_data_results, 'rock_toxicity_negative_aeg', 'rock_v6_1_toxicity_negative_aeg', 'Real Data Negative AEG', ylim=(-0.5,0.5))
scatterplot(real_data_results, 'rock_toxicity_positive_aeg', 'rock_v6_1_toxicity_positive_aeg', 'Real Data Positive AEG', ylim=(-0.5,0.5))

# %%
toxic_scores = real_data.query('toxicity == True')['rock_toxicity']
non_toxic_scores = real_data.query('toxicity == False')['rock_toxicity']
sns.distplot( non_toxic_scores , color="skyblue", axlabel='all')
sns.distplot( toxic_scores , color="red", axlabel='all')
plt.figure()

# %%
toxic_scores = real_data.query('toxicity == True')['rock_v6_1_toxicity']
non_toxic_scores = real_data.query('toxicity == False')['rock_v6_1_toxicity']
sns.distplot( non_toxic_scores , color="skyblue", axlabel='all')
sns.distplot( toxic_scores , color="red", axlabel='all')
plt.figure()

# %%
def plot_histogram(data, identity, model, label_col='toxicity'):
    toxic_scores = data.query(identity + ' == True & ' + label_col + ' == True')[model]
    non_toxic_scores = data.query(identity + ' == True & '+ label_col + ' == False')[model]
    sns.distplot( non_toxic_scores , color="skyblue", axlabel=identity)
    sns.distplot( toxic_scores , color="red", axlabel=identity)
    plt.figure()

# %%
plot_histogram(real_data, 'homosexual_gay_or_lesbian', 'rock_toxicity')
plot_histogram(real_data, 'homosexual_gay_or_lesbian', 'rock_v6_1_toxicity')

# %%
plot_histogram(real_data, 'heterosexual', 'rock_toxicity')
plot_histogram(real_data, 'heterosexual', 'rock_v6_1_toxicity')

# %%
plot_histogram(real_data, 'transgender', 'rock_toxicity')
plot_histogram(real_data, 'transgender', 'rock_v6_1_toxicity')

# %%
plot_histogram(madlibs, 'homosexual', 'Rock:TOXICITY', label_col='label_bool')
#plot_histogram(madlibs, 'homosexual', 'RockV5_1:TOXICITY', label_col='label_bool')
plot_histogram(madlibs, 'homosexual', 'RockV6_1:TOXICITY', label_col='label_bool')

# %%
plot_histogram(madlibs, 'gay', 'Rock:TOXICITY', label_col='label_bool')
#plot_histogram(madlibs, 'gay', 'RockV5_1:TOXICITY', label_col='label_bool')
plot_histogram(madlibs, 'gay', 'RockV6_1:TOXICITY', label_col='label_bool')

# %%
real_data['diff'] = real_data['rock_v6_1_toxicity'] - real_data['rock_toxicity']

# %%
look = real_data[real_data['homosexual_gay_or_lesbian'] & (real_data.comment_text.str.len() < 100)].sort_values('diff', ascending=False)[['comment_text', 'rock_v6_1_toxicity', 'rock_toxicity', 'toxicity']]

# %%
pd.options.display.max_colwidth=200

# %%
look[~look.toxicity]
# Out:
#                                                                                                 comment_text  \
# 1406764            I agree the law should. But adding gays to if won't do that. Elimination of the law will.
# 974324   How can ANYBODY question the republicans love for gay people.  Moore is a standard republican.  Lol
# 35079                                         So gay CIVIL marriages are not sacramental marriages. So what?
# 1749323                     i hear some believe the fires were caused by tolerance of homosexuality :D :D :D
# 74918                                               How is our right to worship  hurting the LGBT community.
# 1103407             this anchor character would have a fit if this were done to Gays.\nwhat ya think anchor.
# 70336            Reminds me of the APA and the protests which led them to remove homosexuality from the DSM.
# 514387                                                       all_married_couples_do,_including_the_gay_ones.
# 1330819                         Homos demand that you accept their fudge packing.  But none of us ever will-
# 1011074                                                 Who was it campaigning for gay marriage rights then?
# 960331                                            If anything, there are fewer obstacles for gays in Oregon.
# 264937                                     Yet the pope himself uses the dreaded "gay" word. Is he in error?
# 629027         Do I have to bake a gay wedding cake, when I'm already happy to bake absolutely anything BUT?
# 1031791                                    BLM and Gays are the most bigoted grandstanding groups in Canada.
# 947219     There's numerous countries over there who will accept gays without a problem. We have dome enough
# 1780625                           Golly, it's not as if they were asked to bake a cake for a gay wedding....
# 1557894                                       Firing gays who marry is OK? Not in my vision of Christianity.
# 805566            Why cherry pick? Why not help all the gay people being prosecuted in all Muslim countries?
# 1329675            This bakery apparently doesn't do cakes for gay marriages, go to the one down the street.
# 1337476                                           Politicising LGBT for polical gain. How low can Notley go.
# 858600                 Social experiments? I seem to have recalled the same sort of "argument" against gays.
# 1687410          Well lets take a survey.. I freely admit I was abused by my lesbian lover.\n\nWho else was?
# 860321                                     Not_always,_but_on_contraception_and_homosexuality,_very_much_so.
# 1775449                  Your conclusions are false, and opposition to gay marriage is thoroughly Christian.
# 617352                     Nonsense, what gives Canada the mandate to be the savior of all Gay`s world wide.
# 682344                                     I fail to see what is so progressive about making fun of gays....
# 666184                         Yea that gay couple had a fight over their winnings and broke up. Oh so sad!!
# 1694481                            Not just any cake, no.  But a wedding cake for a gay wedding?  Certainly.
# 1051404                                              Yes, he could write about homophobia among G&M posters.
# 1172722                      I'm not gay and the feel of Liberal hands on my hips makes me  feel very uneasy
# ...                                                                                                      ...
# 1163189                                                                 Because it's the purview of gay men.
# 398095                                                                                                "Gay"?
# 56399                                                          I recently found out that I too am a lesbian.
# 217653                                    A gay relationship - the safest place for a man to be - literally!
# 345568                                                     Articles like this make me so glad that I am gay.
# 117804             and bacon, wrapping scallops (served at gay weddings).  Two out of three is almost there.
# 802331                                                                            Homosexuals are men right?
# 1186701                                                        A high % of gay men ask for a second opinion.
# 638824                                                Gay-Straight Alliances: united in our contradictions!!
# 59454          Justine heard that Petronas was getting out of BC as he was dancing in the Halifax Gay Parade
# 1621472                                      The pride rests in no longer being ashamed of being homosexual.
# 1190908                                    BLM will expect the gay men of the LBGT to come to their defense.
# 506072    Show the peer-reviewed genetic-based scientific evidence that these people were "born homosexual".
# 1402477                      I enjoy their acceptance of gay people and their ordained female clergy myself.
# 356372          In protest, Jeff will be tuning in a gay sitcom on Monday nights with his snowflake friends.
# 1747604                                          Sodomitic acts are not allowed for anyone, gay or straight.
# 375843                                   Many want the same thing for gay sex, that it be within a marriage.
# 1605642                                                                               I think I'm a lesbian.
# 1785717                                                                        She makes me happy to be gay!
# 1199133  Sounds like Jeff will be tuning in to a gay sitcom on Monday Nights with his salad tossing friends.
# 989274               Married Gay men and woman refer to their partners as husband and wife all the time.....
# 670693                                      And it's the ONLY gay group approved by Holy Mother Church.  :-)
# 298249                                The dude in your image is from famed gay erotic artist Tom of Finland.
# 684401                                                               Yes. Even gay scouts and scout leaders.
# 980207                                                                  As is a trans women being a lesbian.
# 928007             The next time he will hit the news is when he will march with Justin in  TO's gay parade.
# 119157                                                   Actually Transgenders don't identify as homosexual.
# 651771                      " A lesbian ,  a native,  and a Rabi are in a life boat ... "  Yadda yadda yadda
# 1724902                                                   Perhaps our lesbian and transgender children also.
# 698117                                                                                         In a gay bar.
#
#          rock_v6_1_toxicity  rock_toxicity  toxicity
# 1406764            0.654985       0.269230     False
# 974324             0.665536       0.327469     False
# 35079              0.668758       0.371487     False
# 1749323            0.766661       0.497704     False
# 74918              0.462051       0.194926     False
# 1103407            0.714343       0.447837     False
# 70336              0.627050       0.378100     False
# 514387             0.498279       0.252223     False
# 1330819            0.763128       0.543329     False
# 1011074            0.422096       0.207238     False
# 960331             0.598021       0.383583     False
# 264937             0.761025       0.559338     False
# 629027             0.714343       0.514162     False
# 1031791            0.661990       0.464657     False
# 947219             0.607978       0.416709     False
# 1780625            0.714343       0.527961     False
# 1557894            0.738868       0.552653     False
# 805566             0.571869       0.391149     False
# 1329675            0.624285       0.447687     False
# 1337476            0.532044       0.358230     False
# 858600             0.534320       0.360584     False
# 1687410            0.543032       0.373168     False
# 860321             0.448349       0.283513     False
# 1775449            0.547246       0.383776     False
# 617352             0.760792       0.604609     False
# 682344             0.814400       0.667566     False
# 666184             0.827373       0.682903     False
# 1694481            0.660227       0.518246     False
# 1051404            0.413419       0.275236     False
# 1172722            0.450739       0.316871     False
# ...                     ...            ...       ...
# 1163189            0.118629       0.596488     False
# 398095             0.258697       0.739241     False
# 56399              0.173936       0.657854     False
# 217653             0.226470       0.714298     False
# 345568             0.279388       0.769831     False
# 117804             0.034894       0.527640     False
# 802331             0.214017       0.712738     False
# 1186701            0.134364       0.641479     False
# 638824             0.050873       0.560265     False
# 59454              0.123254       0.639017     False
# 1621472            0.197532       0.719185     False
# 1190908            0.254286       0.784269     False
# 506072             0.011669       0.544509     False
# 1402477            0.112127       0.646351     False
# 356372             0.076941       0.614235     False
# 1747604            0.119902       0.666710     False
# 375843             0.133304       0.696964     False
# 1605642            0.117452       0.689651     False
# 1785717            0.294146       0.874753     False
# 1199133            0.096303       0.681045     False
# 989274             0.052441       0.637414     False
# 670693             0.121087       0.711453     False
# 298249             0.007354       0.600654     False
# 684401             0.143357       0.746505     False
# 980207             0.163880       0.773871     False
# 928007             0.088582       0.704140     False
# 119157             0.216030       0.836602     False
# 651771             0.110002       0.752288     False
# 1724902            0.070085       0.712801     False
# 698117             0.155729       0.847013     False
#
# [385 rows x 4 columns]
